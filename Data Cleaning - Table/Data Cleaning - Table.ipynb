# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## **Cleaning up the table**
# ### **Example 1 – Unwise data collection**

# %%
from os import listdir
FileNames = listdir('Speeches')
print(FileNames)
# Out:
# ['NewHampshireFeb10_2020.txt', 'FayettevilleSep19_2020.txt', 'ToledoJan9_2020.txt', 'NewHampshireAug28_2020.txt', 'TexasSep23_2019.txt', 'MindenSep12_2020.txt', 'LasVegasFeb21_2020.txt', 'Winston-SalemSep8_2020.txt', 'FayettevilleSep9_2019.txt', 'PhoenixFeb19_2020.txt', 'MinneapolisOct10_2019.txt', 'LatrobeSep3_2020.txt', 'BemidjiSep18_2020.txt', 'BattleCreekDec19_2019.txt', 'GreenvilleJul17_2019.txt', 'TulsaJun20_2020.txt', 'DesMoinesJan30_2020.txt', 'HersheyDec10_2019.txt', 'LexingtonNov4_2019.txt', 'OhioSep21_2020.txt', 'NewHampshireAug15_2019.txt', 'NewMexicoSep16_2019.txt', 'MilwaukeeJan14_2020.txt', 'HendersonSep13_2020.txt', 'TupeloNov1_2019.txt', 'CharlotteMar2_2020.txt', 'WildwoodJan28_2020.txt', 'YumaAug18_2020.txt', 'CharlestonFeb28_2020.txt', 'PittsburghSep22_2020.txt', 'CincinnatiAug1_2019.txt', 'ColoradorSpringsFeb20_2020.txt', 'FreelandSep10_2020.txt', 'DallasOct17_2019.txt', 'MosineeSep17_2020.txt']

# %%
import pandas as pd
speech_df = pd.DataFrame(index=range(len(FileNames)),columns=['File Name','The Content'])
print(speech_df)
# Out:
#    File Name The Content
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
# 5        NaN         NaN
# 6        NaN         NaN
# 7        NaN         NaN
# 8        NaN         NaN
# 9        NaN         NaN
# 10       NaN         NaN
# 11       NaN         NaN
# 12       NaN         NaN
# 13       NaN         NaN
# 14       NaN         NaN
# 15       NaN         NaN
# 16       NaN         NaN
# 17       NaN         NaN
# 18       NaN         NaN
# 19       NaN         NaN
# 20       NaN         NaN
# 21       NaN         NaN
# 22       NaN         NaN
# 23       NaN         NaN
# 24       NaN         NaN
# 25       NaN         NaN
# 26       NaN         NaN
# 27       NaN         NaN
# 28       NaN         NaN
# 29       NaN         NaN
# 30       NaN         NaN
# 31       NaN         NaN
# 32       NaN         NaN
# 33       NaN         NaN
# 34       NaN         NaN

# %%
for i,f_name in enumerate(FileNames):
    f = open('Speeches/' + f_name, "r", encoding='utf-8')
    f_content = f.readlines()
    f.close()
    
    speech_df.at[i,'File Name'] = f_name
    speech_df.at[i,'The Content'] = f_content[0]

# %%
speech_df.columns = ['FileName','Content']

# %%
speech_df
# Out:
#                           FileName  \
# 0       NewHampshireFeb10_2020.txt
# 1       FayettevilleSep19_2020.txt
# 2              ToledoJan9_2020.txt
# 3       NewHampshireAug28_2020.txt
# 4              TexasSep23_2019.txt
# 5             MindenSep12_2020.txt
# 6           LasVegasFeb21_2020.txt
# 7       Winston-SalemSep8_2020.txt
# 8        FayettevilleSep9_2019.txt
# 9            PhoenixFeb19_2020.txt
# 10       MinneapolisOct10_2019.txt
# 11            LatrobeSep3_2020.txt
# 12           BemidjiSep18_2020.txt
# 13       BattleCreekDec19_2019.txt
# 14        GreenvilleJul17_2019.txt
# 15             TulsaJun20_2020.txt
# 16         DesMoinesJan30_2020.txt
# 17           HersheyDec10_2019.txt
# 18          LexingtonNov4_2019.txt
# 19              OhioSep21_2020.txt
# 20      NewHampshireAug15_2019.txt
# 21         NewMexicoSep16_2019.txt
# 22         MilwaukeeJan14_2020.txt
# 23         HendersonSep13_2020.txt
# 24             TupeloNov1_2019.txt
# 25          CharlotteMar2_2020.txt
# 26          WildwoodJan28_2020.txt
# 27              YumaAug18_2020.txt
# 28        CharlestonFeb28_2020.txt
# 29        PittsburghSep22_2020.txt
# 30         CincinnatiAug1_2019.txt
# 31  ColoradorSpringsFeb20_2020.txt
# 32          FreelandSep10_2020.txt
# 33            DallasOct17_2019.txt
# 34           MosineeSep17_2020.txt
#
#                                               Content
# 0   Hello, Manchester, and I am thrilled to be in ...
# 1   What a crowd, what a crowd. Get those people o...
# 2   Well, thank you very much. Vice President Mike...
# 3   Hello, everybody. Hello, everybody. Wow. Hello...
# 4   Hello, Houston. I am so thrilled to be here in...
# 5   Well, I thank you very much. So I want to star...
# 6   Well, thank you very much. And hello Las Vegas...
# 7   Well, thank you very much. Thank you. Thank yo...
# 8    Thank you everybody. Thank you and Vice Presi...
# 9    Thank you very much, Phoenix. We love to be b...
# 10  Thank you very much. Thank you, Minnesota. Thi...
# 11  So thank you Pennsylvania, very much. I'm thri...
# 12  There's a lot of people. That's great. Thank y...
# 13  Thank you. Thank you. Thank you to Vice Presid...
# 14  Thank you very much. Thank you. Thank you. Tha...
# 15  Thank you, thank you. So we begin, Oklahoma, w...
# 16  I worked so hard for this state. I worked so h...
# 17   Well, thank you to Vice President Pence. Than...
# 18  Thank you very much and thank you to the origi...
# 19  Wow, that's a big crowd. This is a big crowd. ...
# 20   Thank you very much everybody. Thank you. Wow...
# 21   Wow, thank you. Thank you, New Mexico. Thank ...
# 22  Well thank you very much. And I'm thrilled to ...
# 23  Thank you, thank you. Wow. Wow, and I'm thrill...
# 24  ell, thank you very much. And hello, Tupelo. T...
# 25  I want to thank you very much. North Carolina,...
# 26  Thank you. Thank you. I love New Jersey and I'...
# 27  Oh, thank you very much, everybody. Thank you....
# 28  Thank you. Thank you. Thank you. All I can say...
# 29  Doesn't have the power. Doesn't have the stayi...
# 30  Thank you all. Thank you very much. Thank you ...
# 31  Hello Colorado. We love Colorado, most beautif...
# 32  We brought you a lot of car plants, Michigan. ...
# 33  Thank you. Thank you very much. Hello Dallas. ...
# 34  Thank you, thank you very much. Thank you very...

# %% [markdown]
# ### **Example 2 – reindexing (Multi-level Indexing)**

# %%
air_df = pd.read_csv('TempData.csv')
air_df
# Out:
#        Temp  Year  Month  Day      Time
# 0      79.0  2016      1    1  00:00:00
# 1      79.0  2016      1    1  00:30:00
# 2      79.0  2016      1    1  01:00:00
# 3      77.0  2016      1    1  01:30:00
# 4      78.0  2016      1    1  02:00:00
# ...     ...   ...    ...  ...       ...
# 20448  77.0  2016     12   31  22:00:00
# 20449  77.0  2016     12   31  22:30:00
# 20450  77.0  2016     12   31  23:00:00
# 20451  77.0  2016     12   31  23:00:00
# 20452  77.0  2016     12   31  23:30:00
#
# [20453 rows x 5 columns]

# %%
air2016_df = air_df.drop(columns=['Year'])

# %%
air2016_df.set_index(['Month','Day','Time'],inplace=True)

# %%
air2016_df
# Out:
#                     Temp
# Month Day Time
# 1     1   00:00:00  79.0
#           00:30:00  79.0
#           01:00:00  79.0
#           01:30:00  77.0
#           02:00:00  78.0
# ...                  ...
# 12    31  22:00:00  77.0
#           22:30:00  77.0
#           23:00:00  77.0
#           23:00:00  77.0
#           23:30:00  77.0
#
# [20453 rows x 1 columns]

# %%
air2016_df.loc[2,24,'00:30:00']
# Out:
#                     Temp
# Month Day Time
# 2     24  00:30:00  77.0

# %% [markdown]
# ### **Example 3 – Intuitive but long column titles**

# %%
response_df = pd.read_csv('OSMI Mental Health in Tech Survey 2019.csv')
response_df.head(1)
# Out:
#    *Are you self-employed?*  \
# 0                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                               True
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                       I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
#
#    ...  \
# 0  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
#
#   What is your age? What is your gender? What country do you *live* in?  \
# 0                25                 Male       United States of America
#
#   What US state or territory do you *live* in? What is your race?  \
# 0                                     Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
#
# [1 rows x 82 columns]

# %%
response_df['Do you know the options for mental health care available under your employer-provided health coverage?']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 347     No
# 348    NaN
# 349    NaN
# 350     No
# 351    Yes
# Name: Do you know the options for mental health care available under your employer-provided health coverage?, Length: 352, dtype: object

# %%
keys = ['Q{}'.format(i) for i in range(1,83)]
columns_dic = pd.Series(response_df.columns,index=keys)

# %%
columns_dic['Q4']
# Out:
# 'Is your primary role within your company related to tech/IT?'

# %%
response_df.columns = keys

# %%
response_df.head(1)
# Out:
#       Q1      Q2    Q3    Q4            Q5  Q6   Q7   Q8            Q9  \
# 0  False  26-100  True  True  I don't know  No  Yes  Yes  I don't know
#
#          Q10  ...  Q73  Q74    Q75 Q76   Q77                       Q78  \
# 0  Very easy  ...  NaN  NaN  False  25  Male  United States of America
#
#         Q79    Q80                       Q81       Q82
# 0  Nebraska  White  United States of America  Nebraska
#
# [1 rows x 82 columns]
